# %% [markdown]
# # 😎 OpenCV를 활용한 운전자 전방주시 알림서비스

# %%
# opencv 설치
# !pip install opencv-python

# 로컬로 돌릴땐 가상환경에 requirements.txt로 설치함함
# 코랩으로 파일을 돌릴때,
# opencv 설치
# 주석풀고 설치하기를 바람
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
# 설치된 opencv 버전확인
print(cv2.__version__)
# Out:
# 4.6.0

# %%
# 이미지는 배열과 같이 처리할 수 있어서 numpy 불러옴
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %matplotlib inline

# %% [markdown]
# ---
# # 💡 헷갈리는 부분 설명 🤔
# ---
# # ✅**%matplotlib inline** 를 쓰는 이유
# 이 코드는 jupyter notebook 을 실행 할때 주로 같이 쓰이는데,<br>
# 쥬피터 노트북을 실행한 브라우저에서 바로 그림을 볼수 있게
# 즉, 브라우저 내부(inline) 에 바로 그려지도록 해주는 코드이다.<br>
# [**%matplotlib inline** 참고 블로그](https://korbillgates.tistory.com/85)
#
# ---
# # [⬇️PIL 참고 블로그 - 이미지 분석 및 처리를 쉽게 할 수 있는 라이브러리(Python Imaging Library : PIL](https://ddolcat.tistory.com/690)
#
# ---

# %%
# from PIL import image가 안되서 설치함
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# 이미지 읽기(PIL)
from PIL import image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-9ca93afa1344> in <module>
#       1 # 이미지 읽기(PIL)
# ----> 2 from PIL import image
#
# ImportError: cannot import name 'image' from 'PIL' (/usr/local/lib/python3.8/dist-packages/PIL/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
