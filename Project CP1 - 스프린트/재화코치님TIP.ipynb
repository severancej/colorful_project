# %% [markdown]
# ---
# # 🐣11/10일 2차 직무별 회의에서 **재화코치🐮님이 알려주신 tip**
# ---

# %% [markdown]
# <br><br>
#
# # ✨ 🐳 재화코치님🐮이 알려주신 **모델을 충분히 학습하기 위한** 학습데이터는 **최소 500장이상** 이다.⭐
# <br><br>
#
# ### 1.⭐github에 **반드시 기록**해라.<br> ➡️진도가 느리더라도 꼭 기록해두는게 유리하다.<br>➡️로컬컴퓨터에서 작업하다가 언제 고장나도 대비할 수 있도록, github에 commit하는 습관이 중요하다.<br>➡️데이터를 여러군데 올려놔서 대비해야 함.　ex) github, 구글드라이브
# <br>
#
# ### 2. 에러가 났을 때 구글링만으로 해결하지 말고, 질문을 올리고 바로 답변을 받을 수 있는 창구를 만들어라. <br> ➡️가장 좋은건 [stackoverflow](https://stackoverflow.com/help/how-to-ask)나 네이버카페 같은 창구를 만들어 놓기.
# <br>
#
# ### 3.⭐**코드를 재사용**이 가능하게 **모듈화** 해놓기
# <br>
#
# ### 4. 기술을 배우는데 **학습기간을 Max 3일**로 정하고, ⭐이해 못해도 **일단 기술구현 해보기**.
# <br>

# %% [markdown]
# ---
# # 🦄내 프로젝트에 대한 재화코치님의 조언
# ---
# ### 🌈프로젝트 기간이 한정되어 있으니, 라벨링작업을 세세히 하지말고<br>일단, 먼저 뭉뚱그려서 먼저 해놓고 , 모델성능보고 2차적으로 판단하기
#
# ✔️ **라벨링 간소화하기** <br><br>
# 예제)
# - 배추김치, 열무김치, 총각김치 ➡️ 김치
# - 흰밥, 현미밥, 흑미밥 ➡️ 밥
# <br><br>
#
# ✔️ **모델훈련시켜보고 성능이 안좋으면**<br><br>
# 1. 라벨링을 세세히 할 건지 ex) 김치 ➡️ 배추김치, 열무김치, 총각김치
# 2. 훈련데이터가 모자란지 판단 후  행동하기 ➡️훈련데이터 최소 500장이상
# <br>

# %% [markdown]
# ---
# <공통적으로 해주신 조언>
# - 모델훈련을 했을 때, 성능이 좋으면 원래 모델성능이 좋아서 일수도 있다.<br><br>
# - **검출이 잘 안 될 때는**<br>검출이 잘 되는 카테고리와 검출이 잘 안 되는 카테고리의 차이점을 꼭 확인해 봐야 한다.
#
# ---

# %% [markdown]
# ✅CP1 최종목표는 모든 걸 다 가져가려하지 말고,<br>
# **하나라도 제대로 배워서 가져가는 걸** 목표로 하기!!!
